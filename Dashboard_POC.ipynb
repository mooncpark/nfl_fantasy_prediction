# %% [markdown]
# <a href="https://colab.research.google.com/github/mooncpark/nfl_fantasy_prediction/blob/main/Dashboard_POC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Proof of Concept
#
# [MVP Mock](https://lookerstudio.google.com/u/1/reporting/b9277c40-6df9-48d2-9cbf-346c0c52b8f3/page/iUELD)
#
# 1. Take the output of our models (dataframe) and export to drive
# 2. Schedule the colab to run daily and overwrite the drive csv or spreadsheet for freshness
# 3. Connect Data Studio to export file as MVP

# %% [markdown]
# ---
#
# ### Method 1: Overwriting CSVs in Drive

# %%
# Imports
import pandas as pd
from google.colab import drive

# %%
# Create a dummy dataframe to replicate the modeling output
drive.mount('/content/drive')
sample_data = pd.read_csv('/content/drive/Shareddrives/NFL Project/project_sample_data.csv')
sample_data.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    week               player team position  standard_points  half_ppr_points  \
# 0     1  Christian McCaffrey   SF       RB             17.0            20.40
# 1     1       Saquon Barkley  NYG       RB             16.7            20.04
# 2     1         James Conner  ARI       RB             15.7            18.84
# 3     1     Justin Jefferson  MIN       WR             15.1            18.12
# 4     1   Travis Etienne Jr.  JAC       RB             14.7            17.64
#
#    ppr_points
# 0       25.50
# 1       25.05
# 2       23.55
# 3       22.65
# 4       22.05

# %%
# Introduce changes
sample_data['standard_points'] = sample_data['standard_points'] + 1
sample_data['half_ppr_points'] = sample_data['standard_points'] * 1.2
sample_data['ppr_points'] = sample_data['standard_points'] * 1.5
sample_data.head()
# Out:
#    week               player team position  standard_points  half_ppr_points  \
# 0     1  Christian McCaffrey   SF       RB             19.0            22.80
# 1     1       Saquon Barkley  NYG       RB             18.7            22.44
# 2     1         James Conner  ARI       RB             17.7            21.24
# 3     1     Justin Jefferson  MIN       WR             17.1            20.52
# 4     1   Travis Etienne Jr.  JAC       RB             16.7            20.04
#
#    ppr_points
# 0       28.50
# 1       28.05
# 2       26.55
# 3       25.65
# 4       25.05

# %%
# Overwrite the existing CSV with a new dataframe
sample_data.to_csv('/content/drive/Shareddrives/NFL Project/project_sample_data.csv')

# %%
# Make sure the changes are reflected in the overwritten file
sample_data_2 = pd.read_csv('/content/drive/Shareddrives/NFL Project/project_sample_data.csv')
sample_data_2.head()
# Out:
#    Unnamed: 0  week               player team position  standard_points  \
# 0           0     1  Christian McCaffrey   SF       RB             19.0
# 1           1     1       Saquon Barkley  NYG       RB             18.7
# 2           2     1         James Conner  ARI       RB             17.7
# 3           3     1     Justin Jefferson  MIN       WR             17.1
# 4           4     1   Travis Etienne Jr.  JAC       RB             16.7
#
#    half_ppr_points  ppr_points
# 0            22.80       28.50
# 1            22.44       28.05
# 2            21.24       26.55
# 3            20.52       25.65
# 4            20.04       25.05

# %% [markdown]
# ---
#
# ### Method 2: Overwriting Spreadsheet in Drive

# %%
# Overwrite existing spreadsheet with a new dataframe

sample_data.to_drive('/content/drive/Shareddrives/NFL Project/project_sample_data')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-d7ee32632150> in <cell line: 1>()
# ----> 1 sample_data.to_drive('/content/drive/Shareddrives/NFL Project/project_sample_data')
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'to_drive'

# %% [markdown]
# ---
#
# ### Scheduling

# %%
# !git clone https://github.com/bitnom/colabctl.git
# Out:
# Cloning into 'colabctl'...
# remote: Enumerating objects: 118, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Total 118 (delta 19), reused 19 (delta 19), pack-reused 98
# Receiving objects: 100% (118/118), 41.93 KiB | 2.47 MiB/s, done.
# Resolving deltas: 100% (64/64), done.

# %% [markdown]
# Our original design planned to use clbctl.py as method to schedule this job daily without having to pay for cloud compute resources. Unfortunately, the package looks to be deprecated now so we will explore the following options:
#
# * Upgrade Colab to Pro+ ($50/month) to use native scheduling
# * Use Google Cloud Scheduler + GCF to schedule the job daily
# * Figure out how to manually schedule a workflow from local machine
# * Demonstrate the proof of concept in the capstone project without implementing the scheduled workflow.
#
# We will try to explore option 3, but will most likely move forward with #4 instead of paying for a solution (given we understand how to get the workflow started with payment).
